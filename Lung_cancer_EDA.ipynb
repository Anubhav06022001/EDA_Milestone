# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('dataset.csv')
df
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         M   65        1               1        1              2
# 1         F   55        1               2        2              1
# 2         F   78        2               2        1              1
# 3         M   60        2               1        1              1
# 4         F   80        1               1        2              1
# ...     ...  ...      ...             ...      ...            ...
# 2995      F   71        2               1        1              2
# 2996      F   75        1               2        1              1
# 2997      F   62        2               2        2              1
# 2998      M   30        1               1        2              2
# 2999      M   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# ...

# %%
df.shape
# Out:
# (3000, 16)

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
#        'ALCOHOL_CONSUMING', 'COUGHING', 'SHORTNESS_OF_BREATH',
#        'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   65        1               1        1              2
# 1      F   55        1               2        2              1
# 2      F   78        2               2        1              1
# 3      M   60        2               1        1              1
# 4      F   80        1               1        2              1
#
#    CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                2        1        2         2                  2         2
# 1                1        2        2         2                  1         1
# 2                1        2        1         2                  1         1
# 3                2        1        2         1                  1         2
# 4                1        2        1         2                  1         1
#
#    SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN LUNG_CANCER
# ...

# %%
df.tail()
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 2995      F   71        2               1        1              2
# 2996      F   75        1               2        1              1
# 2997      F   62        2               2        2              1
# 2998      M   30        1               1        2              2
# 2999      M   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 2995                2        1        1         1                  1
# 2996                1        2        2         2                  2
# 2997                2        2        2         2                  1
# 2998                2        2        2         2                  2
# 2999                1        1        2         2                  2
#
#       COUGHING  SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN  \
# 2995         2                    1                      1           2
# ...

# %%
df.sample(2)
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 2892      M   76        1               1        1              1
# 1787      F   58        1               2        1              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 2892                2        1        1         1                  2
# 1787                2        1        2         1                  1
#
#       COUGHING  SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN  \
# 2892         2                    1                      2           2
# 1787         2                    2                      1           1
#
#      LUNG_CANCER
# 2892         YES
# 1787          NO

# %%
df.describe()
# Out:
#                AGE      SMOKING  YELLOW_FINGERS      ANXIETY  PEER_PRESSURE  \
# count  3000.000000  3000.000000     3000.000000  3000.000000    3000.000000
# mean     55.169000     1.491000        1.514000     1.494000       1.499000
# std      14.723746     0.500002        0.499887     0.500047       0.500082
# min      30.000000     1.000000        1.000000     1.000000       1.000000
# 25%      42.000000     1.000000        1.000000     1.000000       1.000000
# 50%      55.000000     1.000000        2.000000     1.000000       1.000000
# 75%      68.000000     2.000000        2.000000     2.000000       2.000000
# max      80.000000     2.000000        2.000000     2.000000       2.000000
#
#        CHRONIC_DISEASE      FATIGUE      ALLERGY     WHEEZING  \
# count      3000.000000  3000.000000  3000.000000  3000.000000
# mean          1.509667     1.489667     1.506667     1.497333
# std           0.499990     0.499977     0.500039     0.500076
# ...

# %%
df.describe(include='all')
# Out:
#        GENDER          AGE      SMOKING  YELLOW_FINGERS      ANXIETY  \
# count    3000  3000.000000  3000.000000     3000.000000  3000.000000
# unique      2          NaN          NaN             NaN          NaN
# top         M          NaN          NaN             NaN          NaN
# freq     1514          NaN          NaN             NaN          NaN
# mean      NaN    55.169000     1.491000        1.514000     1.494000
# std       NaN    14.723746     0.500002        0.499887     0.500047
# min       NaN    30.000000     1.000000        1.000000     1.000000
# 25%       NaN    42.000000     1.000000        1.000000     1.000000
# 50%       NaN    55.000000     1.000000        2.000000     1.000000
# 75%       NaN    68.000000     2.000000        2.000000     2.000000
# max       NaN    80.000000     2.000000        2.000000     2.000000
#
#         PEER_PRESSURE  CHRONIC_DISEASE      FATIGUE      ALLERGY     WHEEZING  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 3000 non-null   object
#  1   AGE                    3000 non-null   int64
#  2   SMOKING                3000 non-null   int64
#  3   YELLOW_FINGERS         3000 non-null   int64
#  4   ANXIETY                3000 non-null   int64
#  5   PEER_PRESSURE          3000 non-null   int64
#  6   CHRONIC_DISEASE        3000 non-null   int64
#  7   FATIGUE                3000 non-null   int64
#  8   ALLERGY                3000 non-null   int64
#  9   WHEEZING               3000 non-null   int64
#  10  ALCOHOL_CONSUMING      3000 non-null   int64
#  11  COUGHING               3000 non-null   int64
#  12  SHORTNESS_OF_BREATH    3000 non-null   int64
#  13  SWALLOWING_DIFFICULTY  3000 non-null   int64
#  14  CHEST_PAIN             3000 non-null   int64
# ...

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         M   65        1               1        1              2
# 1         F   55        1               2        2              1
# 2         F   78        2               2        1              1
# 3         M   60        2               1        1              1
# 4         F   80        1               1        2              1
# ...     ...  ...      ...             ...      ...            ...
# 2995      F   71        2               1        1              2
# 2996      F   75        1               2        1              1
# 2997      F   62        2               2        2              1
# 2998      M   30        1               1        2              2
# 2999      M   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# ...

# %%
df.describe()
# Out:
#                AGE      SMOKING  YELLOW_FINGERS      ANXIETY  PEER_PRESSURE  \
# count  2998.000000  2998.000000     2998.000000  2998.000000    2998.000000
# mean     55.171448     1.491328        1.514009     1.493996       1.498666
# std      14.728302     0.500008        0.499887     0.500047       0.500082
# min      30.000000     1.000000        1.000000     1.000000       1.000000
# 25%      42.000000     1.000000        1.000000     1.000000       1.000000
# 50%      55.000000     1.000000        2.000000     1.000000       1.000000
# 75%      68.000000     2.000000        2.000000     2.000000       2.000000
# max      80.000000     2.000000        2.000000     2.000000       2.000000
#
#        CHRONIC_DISEASE      FATIGUE      ALLERGY     WHEEZING  \
# count      2998.000000  2998.000000  2998.000000  2998.000000
# mean          1.509673     1.489660     1.507005     1.497332
# std           0.499990     0.499976     0.500034     0.500076
# ...

# %%
df.dtypes
# Out:
# GENDER                   object
# AGE                       int64
# SMOKING                   int64
# YELLOW_FINGERS            int64
# ANXIETY                   int64
# PEER_PRESSURE             int64
# CHRONIC_DISEASE           int64
# FATIGUE                   int64
# ALLERGY                   int64
# WHEEZING                  int64
# ALCOHOL_CONSUMING         int64
# COUGHING                  int64
# SHORTNESS_OF_BREATH       int64
# SWALLOWING_DIFFICULTY     int64
# CHEST_PAIN                int64
# LUNG_CANCER              object
# dtype: object

# %%
df['CHEST_PAIN']
# Out:
# 0       1
# 1       2
# 2       1
# 3       2
# 4       2
#        ..
# 2995    2
# 2996    1
# 2997    2
# 2998    2
# 2999    1
# Name: CHEST_PAIN, Length: 2998, dtype: int64

# %%
df_copy=df.copy()
df_copy
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         M   65        1               1        1              2
# 1         F   55        1               2        2              1
# 2         F   78        2               2        1              1
# 3         M   60        2               1        1              1
# 4         F   80        1               1        2              1
# ...     ...  ...      ...             ...      ...            ...
# 2995      F   71        2               1        1              2
# 2996      F   75        1               2        1              1
# 2997      F   62        2               2        2              1
# 2998      M   30        1               1        2              2
# 2999      M   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# ...

# %%
df_copy['GENDER']
# Out:
# 0       M
# 1       F
# 2       F
# 3       M
# 4       F
#        ..
# 2995    F
# 2996    F
# 2997    F
# 2998    M
# 2999    M
# Name: GENDER, Length: 2998, dtype: object

# %%
df_copy['GENDER']=df_copy['GENDER'].str.replace("M","1").str.replace("F","0")

# %%
df_copy['GENDER']
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 2995    0
# 2996    0
# 2997    0
# 2998    1
# 2999    1
# Name: GENDER, Length: 2998, dtype: object

# %%
df_copy['GENDER'].astype(int)
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 2995    0
# 2996    0
# 2997    0
# 2998    1
# 2999    1
# Name: GENDER, Length: 2998, dtype: int32

# %%
df_copy.GENDER.dtype
# Out:
# dtype('int32')

# %%
df_copy.head()
# Out:
#    GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0       1   65        1               1        1              2
# 1       0   55        1               2        2              1
# 2       0   78        2               2        1              1
# 3       1   60        2               1        1              1
# 4       0   80        1               1        2              1
#
#    CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                2        1        2         2                  2         2
# 1                1        2        2         2                  1         1
# 2                1        2        1         2                  1         1
# 3                2        1        2         1                  1         2
# 4                1        2        1         2                  1         1
#
#    SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN LUNG_CANCER
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2998 entries, 0 to 2999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 2998 non-null   int32
#  1   AGE                    2998 non-null   int64
#  2   SMOKING                2998 non-null   int64
#  3   YELLOW_FINGERS         2998 non-null   int64
#  4   ANXIETY                2998 non-null   int64
#  5   PEER_PRESSURE          2998 non-null   int64
#  6   CHRONIC_DISEASE        2998 non-null   int64
#  7   FATIGUE                2998 non-null   int64
#  8   ALLERGY                2998 non-null   int64
#  9   WHEEZING               2998 non-null   int64
#  10  ALCOHOL_CONSUMING      2998 non-null   int64
#  11  COUGHING               2998 non-null   int64
#  12  SHORTNESS_OF_BREATH    2998 non-null   int64
#  13  SWALLOWING_DIFFICULTY  2998 non-null   int64
#  14  CHEST_PAIN             2998 non-null   int64
# ...

# %%
df_copy.describe()
# Out:
#             GENDER          AGE      SMOKING  YELLOW_FINGERS      ANXIETY  \
# count  2998.000000  2998.000000  2998.000000     2998.000000  2998.000000
# mean      0.504336    55.171448     1.491328        1.514009     1.493996
# std       0.500065    14.728302     0.500008        0.499887     0.500047
# min       0.000000    30.000000     1.000000        1.000000     1.000000
# 25%       0.000000    42.000000     1.000000        1.000000     1.000000
# 50%       1.000000    55.000000     1.000000        2.000000     1.000000
# 75%       1.000000    68.000000     2.000000        2.000000     2.000000
# max       1.000000    80.000000     2.000000        2.000000     2.000000
#
#        PEER_PRESSURE  CHRONIC_DISEASE      FATIGUE      ALLERGY     WHEEZING  \
# count    2998.000000      2998.000000  2998.000000  2998.000000  2998.000000
# mean        1.498666         1.509673     1.489660     1.507005     1.497332
# ...

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['AGE'].dropna(),kde=True,bins=20,color='skyblue')
plt.title('Distribution of AGE')
plt.xlabel("AGE")
plt.ylabel('frequency')
plt.show()

# %%
#insighst>> dist of age is not skewed

# %%
df_copy.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
#        'ALCOHOL_CONSUMING', 'COUGHING', 'SHORTNESS_OF_BREATH',
#        'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
sns.countplot(x='SWALLOWING_DIFFICULTY',data=df,palette='viridis')
# Out:
# <Axes: xlabel='SWALLOWING_DIFFICULTY', ylabel='count'>

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
#        'ALCOHOL_CONSUMING', 'COUGHING', 'SHORTNESS_OF_BREATH',
#        'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2998 entries, 0 to 2999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 2998 non-null   int32
#  1   AGE                    2998 non-null   int64
#  2   SMOKING                2998 non-null   int64
#  3   YELLOW_FINGERS         2998 non-null   int64
#  4   ANXIETY                2998 non-null   int64
#  5   PEER_PRESSURE          2998 non-null   int64
#  6   CHRONIC_DISEASE        2998 non-null   int64
#  7   FATIGUE                2998 non-null   int64
#  8   ALLERGY                2998 non-null   int64
#  9   WHEEZING               2998 non-null   int64
#  10  ALCOHOL_CONSUMING      2998 non-null   int64
#  11  COUGHING               2998 non-null   int64
#  12  SHORTNESS_OF_BREATH    2998 non-null   int64
#  13  SWALLOWING_DIFFICULTY  2998 non-null   int64
#  14  CHEST_PAIN             2998 non-null   int64
# ...

# %%
sns.countplot(x = 'FATIGUE', data = df, palette = 'pastel')
# Out:
# <Axes: xlabel='FATIGUE', ylabel='count'>

# %%
#insights-->approx same no of people have coughing and swallowing difficulty

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
#        'ALCOHOL_CONSUMING', 'COUGHING', 'SHORTNESS_OF_BREATH',
#        'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
sns.countplot(x = 'GENDER', data = df, palette = 'pastel')
# Out:
# <Axes: xlabel='GENDER', ylabel='count'>

# %%
sns.countplot(x = 'SMOKING', data = df, palette = 'bright')
# Out:
# <Axes: xlabel='SMOKING', ylabel='count'>

# %%
sns.countplot(x = 'ALCOHOL_CONSUMING', data = df, palette = 'dark')
# Out:
# <Axes: xlabel='ALCOHOL_CONSUMING', ylabel='count'>

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
#        'ALCOHOL_CONSUMING', 'COUGHING', 'SHORTNESS_OF_BREATH',
#        'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
sns.scatterplot(x = 'SMOKING', y = 'LUNG_CANCER', data = df)
# Out:
# <Axes: xlabel='SMOKING', ylabel='LUNG_CANCER'>
